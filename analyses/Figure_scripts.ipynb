# %%
from PIL import Image

# List of PNG image paths
image_paths = [
    "/Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_16_02 PM.png",
    "/Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_39_49 PM.png",
    "/Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_40_31 PM.png",
    "/Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_42_12 PM.png",
    "/Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_43_53 PM.png",
    "/Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_45_15 PM.png"
]

# Process each image
for img_path in image_paths:
    try:
        # Open the PNG image
        img = Image.open(img_path)

        # Create the new TIFF filename
        png_path = img_path.replace(".png", ".png")

        # Save the image as TIFF with 300 DPI
        img.save(tiff_path, dpi=(300, 300), format="PNG")

        print(f"Converted: {img_path} → {png_path}")
    except Exception as e:
        print(f"Error processing {img_path}: {e}")
# Out:
# Converted: /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_16_02 PM.png → /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_16_02 PM.png
# Converted: /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_39_49 PM.png → /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_39_49 PM.png
# Converted: /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_40_31 PM.png → /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_40_31 PM.png
# Converted: /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_42_12 PM.png → /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_42_12 PM.png
# Converted: /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_43_53 PM.png → /Users/yaolab/Downloads/neuroglancer-screenshot-w3892px-h2604px-at-3_3_2025-3_43_53 PM.png
# ...
